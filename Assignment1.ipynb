# %% [markdown]
# # Importing required Libariries

# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows',None)

# %% [markdown]
# # Importing Dataset

# %%
df=pd.read_excel('C:/Users/Kiran kumar T/Desktop/iris.xlsx')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
#check the information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  147 non-null    float64
#  2   SepalWidthCm   149 non-null    float64
#  3   PetalLengthCm  149 non-null    float64
#  4   PetalWidthCm   149 non-null    float64
#  5   Species        149 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#check the dataset dimension
df.shape
# Out:
# (150, 6)

# %%
#checking the data type of the dataset
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# checking the variables in column section.
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#statistics summary of dataset
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     147.000000    149.000000     149.000000    149.000000
# mean    75.500000       5.841497      3.056376       3.722819      1.191275
# std     43.445368       0.835254      0.434076       1.793951      0.760328
# min      1.000000       4.300000      2.000000       0.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.500000      0.300000
# 50%     75.500000       5.800000      3.000000       4.300000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Heatmap for Null value for data.
plt.figure(figsize=(12,9))
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %%
#Check the null values in dataset
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     1
# PetalLengthCm    1
# PetalWidthCm     1
# Species          1
# dtype: int64

# %%
#filling the missing values for categorical terms by mode
df['Species']=df['Species'].fillna(df['Species'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     1
# PetalLengthCm    1
# PetalWidthCm     1
# Species          0
# dtype: int64

# %%
#filling the missing values for numerical terms by mean
df['SepalLengthCm']=df['SepalLengthCm'].fillna(df['SepalLengthCm'].mean())
df['SepalWidthCm']=df['SepalWidthCm'].fillna(df['SepalWidthCm'].mean())
df['PetalLengthCm']=df['PetalLengthCm'].fillna(df['PetalLengthCm'].mean())
df['PetalWidthCm']=df['PetalWidthCm'].fillna(df['PetalWidthCm'].mean())

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Converting the Object attributes into Numerical attributes by using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=l.fit_transform(df[i].values)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1       5.100000      3.500000       1.400000      0.200000        0
# 1      2       4.900000      3.000000       1.400000      0.200000        0
# 2      3       4.700000      3.200000       1.300000      0.200000        0
# 3      4       4.600000      3.100000       1.500000      0.200000        0
# 4      5       5.000000      3.600000       1.400000      0.200000        0
# 5      6       5.400000      3.900000       1.700000      0.400000        0
# 6      7       4.600000      3.400000       1.400000      0.300000        0
# 7      8       5.000000      3.400000       1.500000      0.200000        0
# 8      9       4.400000      2.900000       1.400000      0.200000        0
# 9     10       4.900000      3.100000       1.500000      0.100000        0
# 10    11       5.400000      3.700000       1.500000      0.200000        0
# ...

# %%
df.dtypes   # converison of datatype can be seen in Species column
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species            int32
# dtype: object

# %%
#statistics summary of all numerical data
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.841497      3.056376       3.722819      1.191275
# std     43.445368       0.826803      0.432617       1.787921      0.757773
# min      1.000000       4.300000      2.000000       0.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.525000      0.300000
# 50%     75.500000       5.800000      3.000000       4.300000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
#           Species
# count  150.000000
# mean     0.986667
# std      0.819123
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# Heatmap Display distribution of data across all level of category.
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
#finding correlation of the dataset
dfcor=df.corr()                                       # Check the correlation of datasets
dfcor
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.708602     -0.399582       0.876298
# SepalLengthCm  0.708602       1.000000     -0.115018       0.853586
# SepalWidthCm  -0.399582      -0.115018      1.000000      -0.407134
# PetalLengthCm  0.876298       0.853586     -0.407134       1.000000
# PetalWidthCm   0.890222       0.810416     -0.360060       0.940719
# Species        0.919005       0.774605     -0.418315       0.926821
#
#                PetalWidthCm   Species
# Id                 0.890222  0.919005
# SepalLengthCm      0.810416  0.774605
# SepalWidthCm      -0.360060 -0.418315
# PetalLengthCm      0.940719  0.926821
# PetalWidthCm       1.000000  0.938242
# Species            0.938242  1.000000

# %%
# Heatmap Display distribution of data across all level of category of correlation dataset.
plt.figure(figsize=(20,10))
sns.heatmap(dfcor,annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing Outliers from the Dataset

# %%
# Boxplot Display distribution of data across all level of category.
df.boxplot(figsize=[20,5])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[1.72054204e+00, 8.99828259e-01, 1.02887890e+00, 1.30352561e+00,
#         1.31252588e+00, 1.20857609e+00],
#        [1.69744751e+00, 1.14253423e+00, 1.30750117e-01, 1.30352561e+00,
#         1.31252588e+00, 1.20857609e+00],
#        [1.67435299e+00, 1.38524020e+00, 3.33101489e-01, 1.35964388e+00,
#         1.31252588e+00, 1.20857609e+00],
#        [1.65125846e+00, 1.50659319e+00, 1.01175686e-01, 1.24740735e+00,
#         1.31252588e+00, 1.20857609e+00],
#        [1.62816394e+00, 1.02118124e+00, 1.26080470e+00, 1.30352561e+00,
#         1.31252588e+00, 1.20857609e+00],
#        [1.60506942e+00, 5.35769303e-01, 1.95658211e+00, 1.13517081e+00,
#         1.04771023e+00, 1.20857609e+00],
#        [1.58197489e+00, 1.50659319e+00, 7.96953095e-01, 1.30352561e+00,
#         1.18011806e+00, 1.20857609e+00],
#        [1.55888037e+00, 1.02118124e+00, 7.96953095e-01, 1.24740735e+00,
#         1.31252588e+00, 1.20857609e+00],
# ...

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1       5.100000      3.500000       1.400000      0.200000        0
# 1      2       4.900000      3.000000       1.400000      0.200000        0
# 2      3       4.700000      3.200000       1.300000      0.200000        0
# 3      4       4.600000      3.100000       1.500000      0.200000        0
# 4      5       5.000000      3.600000       1.400000      0.200000        0
# 5      6       5.400000      3.900000       1.700000      0.400000        0
# 6      7       4.600000      3.400000       1.400000      0.300000        0
# 7      8       5.000000      3.400000       1.500000      0.200000        0
# 8      9       4.400000      2.900000       1.400000      0.200000        0
# 9     10       4.900000      3.100000       1.500000      0.100000        0
# 10    11       5.400000      3.700000       1.500000      0.200000        0
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df_new.shape
# Out:
# (149, 6)

# %%
Data_loss=((150-149)/150*100)
Data_loss
# Out:
# 0.6666666666666667

# %% [markdown]
# # Checking Skewness of the dataset

# %%
#since the skewness is between -0.5 to 0.5 Hence skewness not found
df.skew()
# Out:
# Id               0.000000
# SepalLengthCm    0.322849
# SepalWidthCm     0.323351
# PetalLengthCm   -0.267881
# PetalWidthCm    -0.098476
# Species          0.024744
# dtype: float64
